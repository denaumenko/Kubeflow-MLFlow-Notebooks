# %% [markdown]
# # Test MLFlow Integration
#
# - start experiment
# - train model
# - save metrics
# - save artifact

# %%
# Please check the requirements.in file for more details
# !pip install -r requirements.txt
# Out:
# Collecting alembic==1.13.2 (from -r requirements.txt (line 7))
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting aniso8601==9.0.1 (from -r requirements.txt (line 9))
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Collecting blinker==1.8.2 (from -r requirements.txt (line 11))
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting boto3==1.34.161 (from -r requirements.txt (line 13))
#   Downloading boto3-1.34.161-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore==1.34.161 (from -r requirements.txt (line 15))
#   Downloading botocore-1.34.161-py3-none-any.whl.metadata (5.7 kB)
# Collecting cachetools==5.4.0 (from -r requirements.txt (line 19))
#   Downloading cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting certifi==2024.7.4 (from -r requirements.txt (line 23))
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer==3.3.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (8.1.7)
# Requirement already satisfied: cloudpickle==3.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (3.0.0)
# Collecting configparser==7.0.0 (from -r requirements.txt (line 35))
#   Downloading configparser-7.0.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy==1.2.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 37)) (1.2.1)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 39)) (0.12.1)
# Collecting databricks-sdk==0.30.0 (from -r requirements.txt (line 41))
#   Downloading databricks_sdk-0.30.0-py3-none-any.whl.metadata (37 kB)
# Collecting deprecated==1.2.14 (from -r requirements.txt (line 43))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: docker==7.1.0 in /home/jovyan/.local/lib/python3.11/site-packages (from -r requirements.txt (line 47)) (7.1.0)
# Requirement already satisfied: entrypoints==0.4 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (0.4)
# Collecting flask==3.0.3 (from -r requirements.txt (line 51))
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting fonttools==4.53.1 (from -r requirements.txt (line 53))
#   Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: gitdb==4.0.11 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 55)) (4.0.11)
# Requirement already satisfied: gitpython==3.1.43 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 57)) (3.1.43)
# Collecting google-auth==2.33.0 (from -r requirements.txt (line 59))
#   Downloading google_auth-2.33.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting graphene==3.3 (from -r requirements.txt (line 61))
#   Downloading graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting graphql-core==3.2.3 (from -r requirements.txt (line 63))
#   Downloading graphql_core-3.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: graphql-relay==3.2.0 in /home/jovyan/.local/lib/python3.11/site-packages (from -r requirements.txt (line 67)) (3.2.0)
# Requirement already satisfied: greenlet==3.0.3 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (3.0.3)
# Collecting gunicorn==22.0.0 (from -r requirements.txt (line 71))
#   Using cached gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: idna==3.7 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 73)) (3.7)
# Collecting importlib-metadata==7.2.1 (from -r requirements.txt (line 75))
#   Using cached importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: itsdangerous==2.2.0 in /home/jovyan/.local/lib/python3.11/site-packages (from -r requirements.txt (line 79)) (2.2.0)
# Requirement already satisfied: jinja2==3.1.4 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 81)) (3.1.4)
# Requirement already satisfied: jmespath==1.0.1 in /home/jovyan/.local/lib/python3.11/site-packages (from -r requirements.txt (line 85)) (1.0.1)
# Requirement already satisfied: joblib==1.4.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 89)) (1.4.2)
# Requirement already satisfied: kiwisolver==1.4.5 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 91)) (1.4.5)
# Collecting mako==1.3.5 (from -r requirements.txt (line 93))
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Collecting markdown==3.6 (from -r requirements.txt (line 95))
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: markupsafe==2.1.5 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 97)) (2.1.5)
# Collecting matplotlib==3.9.2 (from -r requirements.txt (line 102))
#   Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting minio==6.0.2 (from -r requirements.txt (line 104))
#   Downloading minio-6.0.2-py2.py3-none-any.whl.metadata (11 kB)
# Collecting mlflow==2.15.1 (from -r requirements.txt (line 106))
#   Using cached mlflow-2.15.1-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.15.1 (from -r requirements.txt (line 108))
#   Using cached mlflow_skinny-2.15.1-py3-none-any.whl.metadata (30 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 110))
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
# Collecting opentelemetry-api==1.26.0 (from -r requirements.txt (line 119))
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk==1.26.0 (from -r requirements.txt (line 124))
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from -r requirements.txt (line 126))
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging==24.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 128)) (24.1)
# Collecting pandas==2.2.2 (from -r requirements.txt (line 133))
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: pillow==10.4.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 135)) (10.4.0)
# Collecting protobuf==5.27.3 (from -r requirements.txt (line 137))
#   Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pyarrow==15.0.2 (from -r requirements.txt (line 139))
#   Using cached pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pyasn1==0.6.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 141)) (0.6.0)
# Requirement already satisfied: pyasn1-modules==0.4.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 145)) (0.4.0)
# Requirement already satisfied: pyparsing==3.1.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 147)) (3.1.2)
# Collecting python-dateutil==2.9.0.post0 (from -r requirements.txt (line 149))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz==2024.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 155)) (2024.1)
# Collecting pyyaml==6.0.2 (from -r requirements.txt (line 160))
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting querystring-parser==1.2.4 (from -r requirements.txt (line 162))
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: requests==2.32.3 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 164)) (2.32.3)
# Requirement already satisfied: rsa==4.9 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 169)) (4.9)
# Collecting s3transfer==0.10.2 (from -r requirements.txt (line 171))
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting scikit-learn==1.5.1 (from -r requirements.txt (line 173))
#   Downloading scikit_learn-1.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting scipy==1.14.0 (from -r requirements.txt (line 177))
#   Downloading scipy-1.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 181)) (1.16.0)
# Requirement already satisfied: smmap==5.0.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 185)) (5.0.1)
# Collecting sqlalchemy==2.0.32 (from -r requirements.txt (line 187))
#   Downloading SQLAlchemy-2.0.32-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting sqlparse==0.5.1 (from -r requirements.txt (line 191))
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tenacity==9.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 193)) (9.0.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 195)) (3.5.0)
# Requirement already satisfied: typing-extensions==4.12.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 197)) (4.12.2)
# Requirement already satisfied: tzdata==2024.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 202)) (2024.1)
# Collecting urllib3==2.2.2 (from -r requirements.txt (line 204))
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting werkzeug==3.0.3 (from -r requirements.txt (line 210))
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wrapt==1.16.0 (from -r requirements.txt (line 212))
#   Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting zipp==3.20.0 (from -r requirements.txt (line 214))
#   Downloading zipp-3.20.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.1 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading boto3-1.34.161-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading botocore-1.34.161-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 327.5 kB/s eta 0:00:0000:0100:02
# Downloading cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading configparser-7.0.0-py3-none-any.whl (16 kB)
# Downloading databricks_sdk-0.30.0-py3-none-any.whl (538 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.8/538.8 kB 10.2 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.1 MB/s eta 0:00:00
# Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.6 MB/s eta 0:00:0000:0100:01m
# Downloading google_auth-2.33.0-py2.py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 8.0 MB/s eta 0:00:00
# Downloading graphene-3.3-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 4.9 MB/s eta 0:00:00a 0:00:01
# Using cached gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Using cached importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 752.5 kB/s eta 0:00:000:00:01
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 5.2 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading minio-6.0.2-py2.py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.5 MB/s eta 0:00:00
# Using cached mlflow-2.15.1-py3-none-any.whl (26.3 MB)
# Using cached mlflow_skinny-2.15.1-py3-none-any.whl (5.5 MB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 12.2 MB/s eta 0:00:0000:0100:01
# Downloading opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.3 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 4.7 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 6.2 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 12.8 MB/s eta 0:00:0000:0100:01
# Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 8.7 MB/s eta 0:00:00:00:01
# Using cached pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 10.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 8.2 MB/s eta 0:00:00a 0:00:01m
# Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 3.4 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 12.2 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading SQLAlchemy-2.0.32-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 13.8 MB/s eta 0:00:00a 0:00:01
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 2.9 MB/s eta 0:00:00
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 7.0 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.3 MB/s eta 0:00:00
# Downloading zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Installing collected packages: aniso8601, zipp, wrapt, werkzeug, urllib3, sqlparse, sqlalchemy, querystring-parser, pyyaml, python-dateutil, protobuf, numpy, markdown, mako, gunicorn, graphql-core, fonttools, configparser, certifi, cachetools, blinker, scipy, pyarrow, pandas, minio, importlib-metadata, google-auth, flask, deprecated, botocore, alembic, scikit-learn, s3transfer, opentelemetry-api, matplotlib, graphene, databricks-sdk, opentelemetry-semantic-conventions, boto3, opentelemetry-sdk, mlflow-skinny, mlflow
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.19.2
#     Uninstalling zipp-3.19.2:
#       Successfully uninstalled zipp-3.19.2
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.19
#     Uninstalling urllib3-1.26.19:
#       Successfully uninstalled urllib3-1.26.19
#   Attempting uninstall: sqlparse
#     Found existing installation: sqlparse 0.5.3
#     Uninstalling sqlparse-0.5.3:
#       Successfully uninstalled sqlparse-0.5.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.30
#     Uninstalling SQLAlchemy-2.0.30:
#       Successfully uninstalled SQLAlchemy-2.0.30
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0
#     Uninstalling python-dateutil-2.9.0:
#       Successfully uninstalled python-dateutil-2.9.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.7
#     Uninstalling Markdown-3.7:
#       Successfully uninstalled Markdown-3.7
#   Attempting uninstall: mako
#     Found existing installation: Mako 1.3.9
#     Uninstalling Mako-1.3.9:
#       Successfully uninstalled Mako-1.3.9
#   Attempting uninstall: gunicorn
#     Found existing installation: gunicorn 23.0.0
#     Uninstalling gunicorn-23.0.0:
#       Successfully uninstalled gunicorn-23.0.0
#   Attempting uninstall: graphql-core
#     Found existing installation: graphql-core 3.2.6
#     Uninstalling graphql-core-3.2.6:
#       Successfully uninstalled graphql-core-3.2.6
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.53.0
#     Uninstalling fonttools-4.53.0:
#       Successfully uninstalled fonttools-4.53.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.3
#     Uninstalling cachetools-5.3.3:
#       Successfully uninstalled cachetools-5.3.3
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.9.0
#     Uninstalling blinker-1.9.0:
#       Successfully uninstalled blinker-1.9.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.0.0
#     Uninstalling importlib_metadata-8.0.0:
#       Successfully uninstalled importlib_metadata-8.0.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.31.0
#     Uninstalling google-auth-2.31.0:
#       Successfully uninstalled google-auth-2.31.0
#   Attempting uninstall: flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.18
#     Uninstalling Deprecated-1.2.18:
#       Successfully uninstalled Deprecated-1.2.18
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.36.22
#     Uninstalling botocore-1.36.22:
#       Successfully uninstalled botocore-1.36.22
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.14.1
#     Uninstalling alembic-1.14.1:
#       Successfully uninstalled alembic-1.14.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.11.2
#     Uninstalling s3transfer-0.11.2:
#       Successfully uninstalled s3transfer-0.11.2
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.30.0
#     Uninstalling opentelemetry-api-1.30.0:
#       Successfully uninstalled opentelemetry-api-1.30.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
#   Attempting uninstall: graphene
#     Found existing installation: graphene 3.4.3
#     Uninstalling graphene-3.4.3:
#       Successfully uninstalled graphene-3.4.3
#   Attempting uninstall: databricks-sdk
#     Found existing installation: databricks-sdk 0.44.1
#     Uninstalling databricks-sdk-0.44.1:
#       Successfully uninstalled databricks-sdk-0.44.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.51b0
#     Uninstalling opentelemetry-semantic-conventions-0.51b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.51b0
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.36.22
#     Uninstalling boto3-1.36.22:
#       Successfully uninstalled boto3-1.36.22
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.30.0
#     Uninstalling opentelemetry-sdk-1.30.0:
#       Successfully uninstalled opentelemetry-sdk-1.30.0
#   Attempting uninstall: mlflow-skinny
#     Found existing installation: mlflow-skinny 2.20.2
#     Uninstalling mlflow-skinny-2.20.2:
#       Successfully uninstalled mlflow-skinny-2.20.2
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 2.20.2
#     Uninstalling mlflow-2.20.2:
#       Successfully uninstalled mlflow-2.20.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp-pipeline-spec 0.6.0 requires protobuf<5,>=4.21.1, but you have protobuf 5.27.3 which is incompatible.
# ml-metadata 1.16.0 requires protobuf<5,>=4.25.2, but you have protobuf 5.27.3 which is incompatible.
# kfp 2.11.0 requires protobuf<5,>=4.21.1, but you have protobuf 5.27.3 which is incompatible.
# kfp 2.11.0 requires urllib3<2.0.0, but you have urllib3 2.2.2 which is incompatible.
# Successfully installed alembic-1.13.2 aniso8601-9.0.1 blinker-1.8.2 boto3-1.34.161 botocore-1.34.161 cachetools-5.4.0 certifi-2024.7.4 configparser-7.0.0 databricks-sdk-0.30.0 deprecated-1.2.14 flask-3.0.3 fonttools-4.53.1 google-auth-2.33.0 graphene-3.3 graphql-core-3.2.3 gunicorn-22.0.0 importlib-metadata-7.2.1 mako-1.3.5 markdown-3.6 matplotlib-3.9.2 minio-6.0.2 mlflow-2.15.1 mlflow-skinny-2.15.1 numpy-1.26.4 opentelemetry-api-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 pandas-2.2.2 protobuf-5.27.3 pyarrow-15.0.2 python-dateutil-2.9.0.post0 pyyaml-6.0.2 querystring-parser-1.2.4 s3transfer-0.10.2 scikit-learn-1.5.1 scipy-1.14.0 sqlalchemy-2.0.32 sqlparse-0.5.1 urllib3-2.2.2 werkzeug-3.0.3 wrapt-1.16.0 zipp-3.20.0

# %%
import os
import warnings

import pandas as pd
import mlflow
import numpy as np

from minio import Minio
from minio.error import BucketAlreadyOwnedByYou
from mlflow.models.signature import infer_signature
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from tenacity import retry, stop_after_attempt, wait_exponential

# suppress warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(
    "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",
    sep=";",
)
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
TARGET_COLUMN = "quality"
train, test = train_test_split(data)

train_x = train.drop([TARGET_COLUMN], axis=1)
test_x = test.drop([TARGET_COLUMN], axis=1)
train_y = train[[TARGET_COLUMN]]
test_y = test[[TARGET_COLUMN]]

# %%
MINIO_HOST = os.environ["MINIO_ENDPOINT_URL"].split("http://")[1]
MINIO_BUCKET = "mlflow"

# %%
# Initialize a MinIO client
mc = Minio(
    endpoint=MINIO_HOST,
    access_key=os.environ["AWS_ACCESS_KEY_ID"],
    secret_key=os.environ["AWS_SECRET_ACCESS_KEY"],
    secure=False,
)

try:
    mc.make_bucket(MINIO_BUCKET)
except BucketAlreadyOwnedByYou:
    print(f"Bucket {MINIO_BUCKET} already exists!")
# Out:
# Bucket mlflow already exists!

# %%
wine_experiment_name = "My Wine Experiment Test"
experiment = mlflow.get_experiment_by_name(wine_experiment_name)
experiment_id = (
    mlflow.create_experiment(name=wine_experiment_name)
    if experiment is None
    else experiment.experiment_id
)

# %%
# check that the experiment was created successfully
assert (
    mlflow.get_experiment(experiment_id).name == wine_experiment_name
), f"Failed to create experiment {wine_experiment_name}!"

# %%
def experiment(alpha, l1_ratio):
    mlflow.sklearn.autolog()
    with mlflow.start_run(run_name="wine_models_test", experiment_id=experiment_id) as run:
        mlflow.set_tag("author", "kf-testing")
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        pred_y = lr.predict(test_x)
        mlflow.log_metric("rmse", np.sqrt(mean_squared_error(test_y, pred_y)))
        mlflow.log_metric("r2", r2_score(test_y, pred_y))
        mlflow.log_metric("mae", mean_absolute_error(test_y, pred_y))

        signature = infer_signature(test_x, pred_y)
        mlflow.sklearn.log_model(
            lr, "model", registered_model_name="wine-elasticnet", signature=signature
        )

    return run

# %%
# run experiments
runs = [
    experiment(0.5, 0.5),
    experiment(1, 0),
    experiment(0, 1),
]
# Out:
# Registered model 'wine-elasticnet' already exists. Creating a new version of this model...
# 2025/02/17 20:54:41 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: wine-elasticnet, version 2
# Created version '2' of model 'wine-elasticnet'.
# 2025/02/17 20:54:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run wine_models_test at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4/runs/b9e1d33a2c624ac7a68f11f935af55f7.
# 2025/02/17 20:54:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4.
# Registered model 'wine-elasticnet' already exists. Creating a new version of this model...
# 2025/02/17 20:54:43 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: wine-elasticnet, version 3
# Created version '3' of model 'wine-elasticnet'.
# 2025/02/17 20:54:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run wine_models_test at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4/runs/91017ec0bb574a5880720461dd5bbd27.
# 2025/02/17 20:54:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4.
# Registered model 'wine-elasticnet' already exists. Creating a new version of this model...
# 2025/02/17 20:54:45 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: wine-elasticnet, version 4
# Created version '4' of model 'wine-elasticnet'.
# 2025/02/17 20:54:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run wine_models_test at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4/runs/deebdd4be8804e428e6760581f24fa18.
# 2025/02/17 20:54:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://mlflow-server.kubeflow.svc.cluster.local:5000/#/experiments/4.

# %%
@retry(
    wait=wait_exponential(multiplier=2, min=1, max=10),
    stop=stop_after_attempt(30),
    reraise=True,
)
def assert_run_finished(client, run_id):
    """Wait for the run to complete successfully."""
    status = client.get_run(run_id).info.status
    assert status == "FINISHED", f"MLFlow run in {status} state."


def assert_has_metrics(client, run_id, metrics):
    """Assert that the run contains the specified metrics."""
    run = client.get_run(run_id)
    for m in metrics:
        assert m in run.data.metrics, f"Metric {m} not found in logged data!"


def assert_model(client, run_id):
    """Assert Model exists."""
    model = client.sklearn.load_model(f"runs:/{run_id}/model")
    assert isinstance(model, ElasticNet), f"Model {model} is not of type ElasticNet!"

# %%
METRICS = ["rmse", "r2", "mae"]

for run in runs:
    run_id = run.info.run_id
    assert_run_finished(mlflow, run_id)
    assert_has_metrics(mlflow, run_id, METRICS)
    assert_model(mlflow, run_id)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
